# %%
import pandas as pd

# %%
data = pd.read_csv('https://raw.githubusercontent.com/densaiko/data_science_learning/main/dataset/insurance.csv')

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data['bmi_categ_lambda'] = data['bmi'].apply(lambda x: 'Medium BMI' if x >= 30 and x <50 else ('Low BMI' if x < 30 else 'High BMI'))
data.head()
# Out:
#    age     sex     bmi  ...     region      charges bmi_categ_lambda
# 0   19  female  27.900  ...  southwest  16884.92400          Low BMI
# 1   18    male  33.770  ...  southeast   1725.55230       Medium BMI
# 2   28    male  33.000  ...  southeast   4449.46200       Medium BMI
# 3   33    male  22.705  ...  northwest  21984.47061          Low BMI
# 4   32    male  28.880  ...  northwest   3866.85520          Low BMI
#
# [5 rows x 8 columns]

# %%
 pd.pivot_table(data, values=['bmi'], index='bmi_categ_lambda', aggfunc={'bmi':['min','max','mean']})
# Out:
#                      bmi
#                      max       mean    min
# bmi_categ_lambda
# High BMI          53.130  52.030000  50.38
# Low BMI           29.925  25.506426  15.96
# Medium BMI        49.060  35.194574  30.00

# %%
data_upper = data.apply(lambda x: x.str.upper() if x.name in ['sex','region','bmi_categ_lambda'] else x)
data_upper.head()
# Out:
#    age     sex     bmi  ...     region      charges bmi_categ_lambda
# 0   19  FEMALE  27.900  ...  SOUTHWEST  16884.92400          LOW BMI
# 1   18    MALE  33.770  ...  SOUTHEAST   1725.55230       MEDIUM BMI
# 2   28    MALE  33.000  ...  SOUTHEAST   4449.46200       MEDIUM BMI
# 3   33    MALE  22.705  ...  NORTHWEST  21984.47061          LOW BMI
# 4   32    MALE  28.880  ...  NORTHWEST   3866.85520          LOW BMI
#
# [5 rows x 8 columns]
